# %% [markdown]
# ## Data Loading

# %%
import h5py
import numpy as np
import pickle

data = h5py.File('/home/sunji/ANN/nytimes_256_angular/nytimes-256-angular.hdf5', 'r')
data_train = np.array(data['train'])
data_test = np.array(data['test'])
with open('/home/sunji/ANN/nytimes_256_angular/clusters_nytimes_256_angular.pkl', 'rb') as f:
    clusters = pickle.load(f)
with open('/home/sunji/ANN/nytimes_256_angular/ground_truth_nytimes_256_angular_0_4_0_5.pkl', 'rb') as f:
    ground_truth_total = pickle.load(f)

# %%
cluster_size = len(clusters)

# %%
ground_truth_total_level = [[[] for _ in range(10000)] for _ in range(cluster_size)]
for clus in range(cluster_size):
    for t in ground_truth_total[clus]:
        ground_truth_total_level[t[0]][t[1]].append(t)

# %%
centroids = []
for cluster in clusters:
    centroids.append(np.mean(cluster))

# %%
ground_truth_total_level[0]
# Out:
# [[(0, 0, 0.4, 0.402, 0),
#   (0, 0, 0.402, 0.404, 0),
#   (0, 0, 0.404, 0.406, 0),
#   (0, 0, 0.406, 0.40800000000000003, 0),
#   (0, 0, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 0, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 0, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 0, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 0, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 0, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 0, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 0, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 0, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 0, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 0, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 0, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 0, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 0, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 0, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 0, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 0, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 0, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 0, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 0, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 0, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 0, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 0, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 0, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 0, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 0, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 0, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 0, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 0, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 0, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 0, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 0, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 0, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 0, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 0, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 0, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 0, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 0, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 0, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 0, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 0, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 0, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 0, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 0, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 0, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 0, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 1, 0.4, 0.402, 0),
#   (0, 1, 0.402, 0.404, 0),
#   (0, 1, 0.404, 0.406, 0),
#   (0, 1, 0.406, 0.40800000000000003, 0),
#   (0, 1, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 1, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 1, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 1, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 1, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 1, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 1, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 1, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 1, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 1, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 1, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 1, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 1, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 1, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 1, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 1, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 1, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 1, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 1, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 1, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 1, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 1, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 1, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 1, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 1, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 1, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 1, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 1, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 1, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 1, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 1, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 1, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 1, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 1, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 1, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 1, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 1, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 1, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 1, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 1, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 1, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 1, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 1, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 1, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 1, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 1, 0.4980000000000001, 0.5000000000000001, 3440)],
#  [(0, 2, 0.4, 0.402, 0),
#   (0, 2, 0.402, 0.404, 0),
#   (0, 2, 0.404, 0.406, 0),
#   (0, 2, 0.406, 0.40800000000000003, 0),
#   (0, 2, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 2, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 2, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 2, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 2, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 2, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 2, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 2, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 2, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 2, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 2, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 2, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 2, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 2, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 2, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 2, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 2, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 2, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 2, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 2, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 2, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 2, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 2, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 2, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 2, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 2, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 2, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 2, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 2, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 2, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 2, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 2, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 2, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 2, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 2, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 2, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 2, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 2, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 2, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 2, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 2, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 2, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 2, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 2, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 2, 0.4960000000000001, 0.4980000000000001, 3440),
#   (0, 2, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 3, 0.4, 0.402, 0),
#   (0, 3, 0.402, 0.404, 0),
#   (0, 3, 0.404, 0.406, 0),
#   (0, 3, 0.406, 0.40800000000000003, 0),
#   (0, 3, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 3, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 3, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 3, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 3, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 3, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 3, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 3, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 3, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 3, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 3, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 3, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 3, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 3, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 3, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 3, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 3, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 3, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 3, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 3, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 3, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 3, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 3, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 3, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 3, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 3, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 3, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 3, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 3, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 3, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 3, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 3, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 3, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 3, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 3, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 3, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 3, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 3, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 3, 0.4840000000000001, 0.4860000000000001, 3440),
#   (0, 3, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 3, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 3, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 3, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 3, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 3, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 3, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 4, 0.4, 0.402, 0),
#   (0, 4, 0.402, 0.404, 0),
#   (0, 4, 0.404, 0.406, 0),
#   (0, 4, 0.406, 0.40800000000000003, 0),
#   (0, 4, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 4, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 4, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 4, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 4, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 4, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 4, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 4, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 4, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 4, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 4, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 4, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 4, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 4, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 4, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 4, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 4, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 4, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 4, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 4, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 4, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 4, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 4, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 4, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 4, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 4, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 4, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 4, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 4, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 4, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 4, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 4, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 4, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 4, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 4, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 4, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 4, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 4, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 4, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 4, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 4, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 4, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 4, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 4, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 4, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 4, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 5, 0.4, 0.402, 0),
#   (0, 5, 0.402, 0.404, 0),
#   (0, 5, 0.404, 0.406, 0),
#   (0, 5, 0.406, 0.40800000000000003, 0),
#   (0, 5, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 5, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 5, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 5, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 5, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 5, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 5, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 5, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 5, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 5, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 5, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 5, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 5, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 5, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 5, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 5, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 5, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 5, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 5, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 5, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 5, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 5, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 5, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 5, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 5, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 5, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 5, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 5, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 5, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 5, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 5, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 5, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 5, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 5, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 5, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 5, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 5, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 5, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 5, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 5, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 5, 0.4880000000000001, 0.4900000000000001, 3440),
#   (0, 5, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 5, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 5, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 5, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 5, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 6, 0.4, 0.402, 0),
#   (0, 6, 0.402, 0.404, 0),
#   (0, 6, 0.404, 0.406, 0),
#   (0, 6, 0.406, 0.40800000000000003, 0),
#   (0, 6, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 6, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 6, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 6, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 6, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 6, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 6, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 6, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 6, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 6, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 6, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 6, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 6, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 6, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 6, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 6, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 6, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 6, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 6, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 6, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 6, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 6, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 6, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 6, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 6, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 6, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 6, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 6, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 6, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 6, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 6, 0.4680000000000001, 0.4700000000000001, 3440),
#   (0, 6, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 6, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 6, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 6, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 6, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 6, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 6, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 6, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 6, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 6, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 6, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 6, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 6, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 6, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 6, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 7, 0.4, 0.402, 0),
#   (0, 7, 0.402, 0.404, 0),
#   (0, 7, 0.404, 0.406, 0),
#   (0, 7, 0.406, 0.40800000000000003, 0),
#   (0, 7, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 7, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 7, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 7, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 7, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 7, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 7, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 7, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 7, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 7, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 7, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 7, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 7, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 7, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 7, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 7, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 7, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 7, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 7, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 7, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 7, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 7, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 7, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 7, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 7, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 7, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 7, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 7, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 7, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 7, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 7, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 7, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 7, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 7, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 7, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 7, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 7, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 7, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 7, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 7, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 7, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 7, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 7, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 7, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 7, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 7, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 8, 0.4, 0.402, 0),
#   (0, 8, 0.402, 0.404, 0),
#   (0, 8, 0.404, 0.406, 0),
#   (0, 8, 0.406, 0.40800000000000003, 0),
#   (0, 8, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 8, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 8, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 8, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 8, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 8, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 8, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 8, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 8, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 8, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 8, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 8, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 8, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 8, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 8, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 8, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 8, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 8, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 8, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 8, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 8, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 8, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 8, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 8, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 8, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 8, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 8, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 8, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 8, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 8, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 8, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 8, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 8, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 8, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 8, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 8, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 8, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 8, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 8, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 8, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 8, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 8, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 8, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 8, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 8, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 8, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 9, 0.4, 0.402, 0),
#   (0, 9, 0.402, 0.404, 0),
#   (0, 9, 0.404, 0.406, 0),
#   (0, 9, 0.406, 0.40800000000000003, 0),
#   (0, 9, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 9, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 9, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 9, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 9, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 9, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 9, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 9, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 9, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 9, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 9, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 9, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 9, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 9, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 9, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 9, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 9, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 9, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 9, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 9, 0.44600000000000006, 0.44800000000000006, 3440),
#   (0, 9, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 9, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 9, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 9, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 9, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 9, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 9, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 9, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 9, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 9, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 9, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 9, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 9, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 9, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 9, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 9, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 9, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 9, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 9, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 9, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 9, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 9, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 9, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 9, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 9, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 9, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 10, 0.4, 0.402, 0),
#   (0, 10, 0.402, 0.404, 0),
#   (0, 10, 0.404, 0.406, 0),
#   (0, 10, 0.406, 0.40800000000000003, 0),
#   (0, 10, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 10, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 10, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 10, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 10, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 10, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 10, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 10, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 10, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 10, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 10, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 10, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 10, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 10, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 10, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 10, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 10, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 10, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 10, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 10, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 10, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 10, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 10, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 10, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 10, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 10, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 10, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 10, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 10, 0.4640000000000001, 0.4660000000000001, 3440),
#   (0, 10, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 10, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 10, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 10, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 10, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 10, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 10, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 10, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 10, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 10, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 10, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 10, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 10, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 10, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 10, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 10, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 10, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 11, 0.4, 0.402, 0),
#   (0, 11, 0.402, 0.404, 0),
#   (0, 11, 0.404, 0.406, 0),
#   (0, 11, 0.406, 0.40800000000000003, 0),
#   (0, 11, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 11, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 11, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 11, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 11, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 11, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 11, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 11, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 11, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 11, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 11, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 11, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 11, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 11, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 11, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 11, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 11, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 11, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 11, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 11, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 11, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 11, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 11, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 11, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 11, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 11, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 11, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 11, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 11, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 11, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 11, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 11, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 11, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 11, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 11, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 11, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 11, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 11, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 11, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 11, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 11, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 11, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 11, 0.4920000000000001, 0.4940000000000001, 3440),
#   (0, 11, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 11, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 11, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 12, 0.4, 0.402, 0),
#   (0, 12, 0.402, 0.404, 0),
#   (0, 12, 0.404, 0.406, 0),
#   (0, 12, 0.406, 0.40800000000000003, 0),
#   (0, 12, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 12, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 12, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 12, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 12, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 12, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 12, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 12, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 12, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 12, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 12, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 12, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 12, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 12, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 12, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 12, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 12, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 12, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 12, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 12, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 12, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 12, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 12, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 12, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 12, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 12, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 12, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 12, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 12, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 12, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 12, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 12, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 12, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 12, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 12, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 12, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 12, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 12, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 12, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 12, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 12, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 12, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 12, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 12, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 12, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 12, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 13, 0.4, 0.402, 0),
#   (0, 13, 0.402, 0.404, 0),
#   (0, 13, 0.404, 0.406, 0),
#   (0, 13, 0.406, 0.40800000000000003, 0),
#   (0, 13, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 13, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 13, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 13, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 13, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 13, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 13, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 13, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 13, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 13, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 13, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 13, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 13, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 13, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 13, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 13, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 13, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 13, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 13, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 13, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 13, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 13, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 13, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 13, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 13, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 13, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 13, 0.4600000000000001, 0.4620000000000001, 3440),
#   (0, 13, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 13, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 13, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 13, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 13, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 13, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 13, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 13, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 13, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 13, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 13, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 13, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 13, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 13, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 13, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 13, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 13, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 13, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 13, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 14, 0.4, 0.402, 0),
#   (0, 14, 0.402, 0.404, 0),
#   (0, 14, 0.404, 0.406, 0),
#   (0, 14, 0.406, 0.40800000000000003, 0),
#   (0, 14, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 14, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 14, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 14, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 14, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 14, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 14, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 14, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 14, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 14, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 14, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 14, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 14, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 14, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 14, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 14, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 14, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 14, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 14, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 14, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 14, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 14, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 14, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 14, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 14, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 14, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 14, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 14, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 14, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 14, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 14, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 14, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 14, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 14, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 14, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 14, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 14, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 14, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 14, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 14, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 14, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 14, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 14, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 14, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 14, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 14, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 15, 0.4, 0.402, 0),
#   (0, 15, 0.402, 0.404, 0),
#   (0, 15, 0.404, 0.406, 0),
#   (0, 15, 0.406, 0.40800000000000003, 0),
#   (0, 15, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 15, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 15, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 15, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 15, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 15, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 15, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 15, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 15, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 15, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 15, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 15, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 15, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 15, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 15, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 15, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 15, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 15, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 15, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 15, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 15, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 15, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 15, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 15, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 15, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 15, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 15, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 15, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 15, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 15, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 15, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 15, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 15, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 15, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 15, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 15, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 15, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 15, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 15, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 15, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 15, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 15, 0.4900000000000001, 0.4920000000000001, 3440),
#   (0, 15, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 15, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 15, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 15, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 16, 0.4, 0.402, 0),
#   (0, 16, 0.402, 0.404, 0),
#   (0, 16, 0.404, 0.406, 0),
#   (0, 16, 0.406, 0.40800000000000003, 0),
#   (0, 16, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 16, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 16, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 16, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 16, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 16, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 16, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 16, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 16, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 16, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 16, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 16, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 16, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 16, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 16, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 16, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 16, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 16, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 16, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 16, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 16, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 16, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 16, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 16, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 16, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 16, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 16, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 16, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 16, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 16, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 16, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 16, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 16, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 16, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 16, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 16, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 16, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 16, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 16, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 16, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 16, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 16, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 16, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 16, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 16, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 16, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 17, 0.4, 0.402, 0),
#   (0, 17, 0.402, 0.404, 0),
#   (0, 17, 0.404, 0.406, 0),
#   (0, 17, 0.406, 0.40800000000000003, 0),
#   (0, 17, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 17, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 17, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 17, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 17, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 17, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 17, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 17, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 17, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 17, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 17, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 17, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 17, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 17, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 17, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 17, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 17, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 17, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 17, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 17, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 17, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 17, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 17, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 17, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 17, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 17, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 17, 0.4600000000000001, 0.4620000000000001, 3440),
#   (0, 17, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 17, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 17, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 17, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 17, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 17, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 17, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 17, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 17, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 17, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 17, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 17, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 17, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 17, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 17, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 17, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 17, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 17, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 17, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 18, 0.4, 0.402, 0),
#   (0, 18, 0.402, 0.404, 0),
#   (0, 18, 0.404, 0.406, 0),
#   (0, 18, 0.406, 0.40800000000000003, 0),
#   (0, 18, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 18, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 18, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 18, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 18, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 18, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 18, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 18, 0.42200000000000004, 0.42400000000000004, 0),
# ...
#   (0, 994, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 994, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 994, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 994, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 994, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 994, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 994, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 994, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 994, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 994, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 994, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 994, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 994, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 994, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 994, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 994, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 994, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 994, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 994, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 994, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 994, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 994, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 994, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 994, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 994, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 994, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 994, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 994, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 994, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 994, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 994, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 994, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 994, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 994, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 994, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 994, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 994, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 994, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 994, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 994, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 994, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 994, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 994, 0.4980000000000001, 0.5000000000000001, 3440)],
#  [(0, 995, 0.4, 0.402, 0),
#   (0, 995, 0.402, 0.404, 0),
#   (0, 995, 0.404, 0.406, 0),
#   (0, 995, 0.406, 0.40800000000000003, 0),
#   (0, 995, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 995, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 995, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 995, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 995, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 995, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 995, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 995, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 995, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 995, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 995, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 995, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 995, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 995, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 995, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 995, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 995, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 995, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 995, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 995, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 995, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 995, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 995, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 995, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 995, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 995, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 995, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 995, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 995, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 995, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 995, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 995, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 995, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 995, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 995, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 995, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 995, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 995, 0.4820000000000001, 0.4840000000000001, 3440),
#   (0, 995, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 995, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 995, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 995, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 995, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 995, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 995, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 995, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 996, 0.4, 0.402, 0),
#   (0, 996, 0.402, 0.404, 0),
#   (0, 996, 0.404, 0.406, 0),
#   (0, 996, 0.406, 0.40800000000000003, 0),
#   (0, 996, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 996, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 996, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 996, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 996, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 996, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 996, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 996, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 996, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 996, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 996, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 996, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 996, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 996, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 996, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 996, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 996, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 996, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 996, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 996, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 996, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 996, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 996, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 996, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 996, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 996, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 996, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 996, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 996, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 996, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 996, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 996, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 996, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 996, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 996, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 996, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 996, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 996, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 996, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 996, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 996, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 996, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 996, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 996, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 996, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 996, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 997, 0.4, 0.402, 0),
#   (0, 997, 0.402, 0.404, 0),
#   (0, 997, 0.404, 0.406, 0),
#   (0, 997, 0.406, 0.40800000000000003, 0),
#   (0, 997, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 997, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 997, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 997, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 997, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 997, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 997, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 997, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 997, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 997, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 997, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 997, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 997, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 997, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 997, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 997, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 997, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 997, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 997, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 997, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 997, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 997, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 997, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 997, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 997, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 997, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 997, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 997, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 997, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 997, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 997, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 997, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 997, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 997, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 997, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 997, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 997, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 997, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 997, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 997, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 997, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 997, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 997, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 997, 0.4940000000000001, 0.4960000000000001, 0),
#   (0, 997, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 997, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 998, 0.4, 0.402, 0),
#   (0, 998, 0.402, 0.404, 0),
#   (0, 998, 0.404, 0.406, 0),
#   (0, 998, 0.406, 0.40800000000000003, 0),
#   (0, 998, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 998, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 998, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 998, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 998, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 998, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 998, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 998, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 998, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 998, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 998, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 998, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 998, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 998, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 998, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 998, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 998, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 998, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 998, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 998, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 998, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 998, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 998, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 998, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 998, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 998, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 998, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 998, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 998, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 998, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 998, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 998, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 998, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 998, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 998, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 998, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 998, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 998, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 998, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 998, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 998, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 998, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 998, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 998, 0.4940000000000001, 0.4960000000000001, 3440),
#   (0, 998, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 998, 0.4980000000000001, 0.5000000000000001, 0)],
#  [(0, 999, 0.4, 0.402, 0),
#   (0, 999, 0.402, 0.404, 0),
#   (0, 999, 0.404, 0.406, 0),
#   (0, 999, 0.406, 0.40800000000000003, 0),
#   (0, 999, 0.40800000000000003, 0.41000000000000003, 0),
#   (0, 999, 0.41000000000000003, 0.41200000000000003, 0),
#   (0, 999, 0.41200000000000003, 0.41400000000000003, 0),
#   (0, 999, 0.41400000000000003, 0.41600000000000004, 0),
#   (0, 999, 0.41600000000000004, 0.41800000000000004, 0),
#   (0, 999, 0.41800000000000004, 0.42000000000000004, 0),
#   (0, 999, 0.42000000000000004, 0.42200000000000004, 0),
#   (0, 999, 0.42200000000000004, 0.42400000000000004, 0),
#   (0, 999, 0.42400000000000004, 0.42600000000000005, 0),
#   (0, 999, 0.42600000000000005, 0.42800000000000005, 0),
#   (0, 999, 0.42800000000000005, 0.43000000000000005, 0),
#   (0, 999, 0.43000000000000005, 0.43200000000000005, 0),
#   (0, 999, 0.43200000000000005, 0.43400000000000005, 0),
#   (0, 999, 0.43400000000000005, 0.43600000000000005, 0),
#   (0, 999, 0.43600000000000005, 0.43800000000000006, 0),
#   (0, 999, 0.43800000000000006, 0.44000000000000006, 0),
#   (0, 999, 0.44000000000000006, 0.44200000000000006, 0),
#   (0, 999, 0.44200000000000006, 0.44400000000000006, 0),
#   (0, 999, 0.44400000000000006, 0.44600000000000006, 0),
#   (0, 999, 0.44600000000000006, 0.44800000000000006, 0),
#   (0, 999, 0.44800000000000006, 0.45000000000000007, 0),
#   (0, 999, 0.45000000000000007, 0.45200000000000007, 0),
#   (0, 999, 0.45200000000000007, 0.45400000000000007, 0),
#   (0, 999, 0.45400000000000007, 0.45600000000000007, 0),
#   (0, 999, 0.45600000000000007, 0.4580000000000001, 0),
#   (0, 999, 0.4580000000000001, 0.4600000000000001, 0),
#   (0, 999, 0.4600000000000001, 0.4620000000000001, 0),
#   (0, 999, 0.4620000000000001, 0.4640000000000001, 0),
#   (0, 999, 0.4640000000000001, 0.4660000000000001, 0),
#   (0, 999, 0.4660000000000001, 0.4680000000000001, 0),
#   (0, 999, 0.4680000000000001, 0.4700000000000001, 0),
#   (0, 999, 0.4700000000000001, 0.4720000000000001, 0),
#   (0, 999, 0.4720000000000001, 0.4740000000000001, 0),
#   (0, 999, 0.4740000000000001, 0.4760000000000001, 0),
#   (0, 999, 0.4760000000000001, 0.4780000000000001, 0),
#   (0, 999, 0.4780000000000001, 0.4800000000000001, 0),
#   (0, 999, 0.4800000000000001, 0.4820000000000001, 0),
#   (0, 999, 0.4820000000000001, 0.4840000000000001, 0),
#   (0, 999, 0.4840000000000001, 0.4860000000000001, 0),
#   (0, 999, 0.4860000000000001, 0.4880000000000001, 0),
#   (0, 999, 0.4880000000000001, 0.4900000000000001, 0),
#   (0, 999, 0.4900000000000001, 0.4920000000000001, 0),
#   (0, 999, 0.4920000000000001, 0.4940000000000001, 0),
#   (0, 999, 0.4940000000000001, 0.4960000000000001, 3440),
#   (0, 999, 0.4960000000000001, 0.4980000000000001, 0),
#   (0, 999, 0.4980000000000001, 0.5000000000000001, 0)],
#  ...]

# %% [markdown]
# ## Prepare Inputs

# %%
from numpy import dot
from numpy.linalg import norm
from scipy import spatial


def jaccard(x1, x2=None, eps=1e-8):
    x1 = x1.astype(bool)
    x2 = x2.astype(bool)
    return 1.0 - np.double(np.bitwise_and(x1, x2).sum()) / np.double(np.bitwise_or(x1, x2).sum())

def euclidean_dist_normalized(x1, x2=None, eps=1e-8):
    if np.isnan(x2):
        return 1.0
    left = x1 / 255.0
    right = x2 / 255.0
    return np.sqrt(((left - right) ** 2).mean())

def angular_dist(x1, x2=None, eps=1e-8):
    cosine_sim = 1 - spatial.distance.cosine(x1, x2)
    distance = np.arccos(cosine_sim) / 3.14159267
    return distance 

train_features = []
train_thresholds = []
train_distances = []
train_targets = []
train_cards = []
slot = 0.002
for query_id in range(8000):
    cardinality = [0 for _ in range(cluster_size)]
    distances2centroids = []
    for cc in centroids:
        distances2centroids.append(angular_dist(data_test[query_id], cc))
    for threshold_id, threshold in enumerate(np.arange(0.4, 0.5, slot)):
        indicator = []
        cards = []
        for cluster_id in range(cluster_size):
            cardinality[cluster_id] += ground_truth_total_level[cluster_id][query_id][threshold_id][-1]
            if cardinality[cluster_id] > 0:
                indicator.append(1)
            else:
                indicator.append(0)
            cards.append(cardinality[cluster_id])
        feature = data_test[query_id]
        train_features.append(feature)
        train_distances.append(distances2centroids)
        train_thresholds.append([threshold+slot])
        train_targets.append(indicator)
        train_cards.append(cards)

test_features = []
test_thresholds = []
test_distances = []
test_targets = []
test_cards = []
slot = 0.002
for query_id in range(8000,10000):
    cardinality = [0 for _ in range(cluster_size)]
    distances2centroids = []
    for cc in centroids:
        distances2centroids.append(angular_dist(data_test[query_id], cc))
    for threshold_id, threshold in enumerate(np.arange(0.4, 0.5, slot)):
        indicator = []
        cards = []
        for cluster_id in range(cluster_size):
            cardinality[cluster_id] += ground_truth_total_level[cluster_id][query_id][threshold_id][-1]
            if cardinality[cluster_id] > 0:
                indicator.append(1)
            else:
                indicator.append(0)
            cards.append(cardinality[cluster_id])
        feature = data_test[query_id]
        test_features.append(feature)
        test_distances.append(distances2centroids)
        test_thresholds.append([threshold+slot])
        test_targets.append(indicator)
        test_cards.append(cards)
# Out:
# /home/sunji/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py:702: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
test_distances[0][0]
# Out:
# 0.5355004546363034

# %%
import torch
import torch.utils.data
batch_size = 128
train_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(torch.FloatTensor(train_features), torch.FloatTensor(train_thresholds), torch.FloatTensor(train_distances), torch.FloatTensor(train_targets), torch.FloatTensor(train_cards)), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(torch.FloatTensor(test_features), torch.FloatTensor(test_thresholds), torch.FloatTensor(test_distances), torch.FloatTensor(test_targets), torch.FloatTensor(test_cards)), batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Multi-label Networks

# %%
from __future__ import print_function
import argparse
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

input_dimension = 256
cluster_dimension = cluster_size
hidden_num = 256
output_num = cluster_size

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.nn1 = nn.Linear(input_dimension, hidden_num)
        self.nn2 = nn.Linear(hidden_num, hidden_num)
#         self.nn3 = nn.Linear(hidden_num, hidden_num)
        
        self.dist1 = nn.Linear(cluster_dimension, hidden_num)
        self.dist2 = nn.Linear(hidden_num, hidden_num)
        
        self.nn4 = nn.Linear(hidden_num, hidden_num)
        self.nn5 = nn.Linear(hidden_num, output_num)
        
        self.thres1 = nn.Linear(1, hidden_num)
        self.thres2 = nn.Linear(hidden_num, 1)

    def forward(self, x, distances, thresholds):
        out1 = F.relu(self.nn1(x))
        out2 = F.relu(self.nn2(out1))
#         out3 = F.relu(self.nn3(out2))
#         print (distances.shape)
        distance1 = F.relu(self.dist1(distances))
        distance2 = F.relu(self.dist2(distance1))
        
        thresholds_1 = F.relu(self.thres1(thresholds))
        thresholds_2 = self.thres2(thresholds_1)

        out4 = F.relu(self.nn4((out2 + distance2) / 2))
        out5 = self.nn5(out2)
        
        probability = F.sigmoid(out5 + thresholds_2)
        return probability

def loss_fn(estimates, targets, cards):
    punish_idx = (estimates < 0.5).float()
    return F.mse_loss(estimates, targets) + 0.0 * torch.log(((0.5 - estimates) * cards * punish_idx).mean() + 1.0)

def print_loss(estimates, targets, cards):
    true_positive = 0.0
    true_negative = 0.0
    false_positive = 0.0
    false_negative = 0.0
    num_elements = estimates.shape[1]
    for est, tar in zip(estimates, targets):
        for i in range(num_elements):
            if est[i] < 0.5 and tar[i] == 0:
                true_negative += 1
            elif est[i] < 0.5 and tar[i] == 1:
                false_negative += 1
            elif est[i] >= 0.5 and tar[i] == 0:
                false_positive += 1
            else:
                true_positive += 1
    if true_positive + false_positive > 0:
        precision = true_positive / (true_positive + false_positive)
    else:
        precision = 1.0
    if true_positive + false_negative > 0:
        recall = true_positive / (true_positive + false_negative)
    else:
        recall = 1.0
    total_card = cards.sum(dim=1)
#     print ('total_card: ', total_card.shape)
    miss_card = torch.FloatTensor([cards[i][((estimates[i] < 0.5).nonzero())].sum() for i in range(cards.shape[0])])
#     print ('miss_card: ', miss_card.shape)
    miss_rate = (miss_card / (total_card + 0.1)).mean()
    return precision, recall, miss_rate

# %%
model = Model()
opt = optim.Adam(model.parameters(), lr=0.001)
for e in range(5):
    model.train()
    for batch_idx, (features, thresholds, distances, targets, cards) in enumerate(train_loader):
        x = Variable(features)
        y = Variable(targets.unsqueeze(1))
        z = Variable(thresholds)
        dists = Variable(distances)
        opt.zero_grad()
        estimates = model(x, dists, z)
        loss = loss_fn(estimates, targets, cards)
        if batch_idx % 100 == 0:
            print('Training: Iteration {0}, Batch {1}, Loss {2}'.format(e, batch_idx, loss.item()))
        loss.backward()
        opt.step()
        next(model.thres1.parameters()).data.clamp_(0)
        next(model.thres2.parameters()).data.clamp_(0)

    model.eval()    
    test_loss = 0.0
    precision = 0.0
    recall = 0.0
    miss_rate = 0.0
    for batch_idx, (features, thresholds, distances, targets, cards) in enumerate(test_loader):
        x = Variable(features)
        y = Variable(targets.unsqueeze(1))
        z = Variable(thresholds)
        dists = Variable(distances)
        estimates = model(x, dists, z)
        loss = loss_fn(estimates, targets, cards)
        test_loss += loss.item()
        prec, rec, miss = print_loss(estimates, targets, cards)
        precision += prec
        recall += rec
        miss_rate += miss
        if batch_idx % 100 == 0:
            print ('Testing: Iteration {0}, Batch {1}, Loss {2}, Precision {3}, Recall {4}, Miss {5}'.format(e, batch_idx, loss.item(), prec, rec, miss))
    test_loss /= len(test_loader)
    precision /= len(test_loader)
    recall /= len(test_loader)
    miss_rate /= len(test_loader)
    print ('Testing: Loss {0}, Precision {1}, Recall {2}, Miss {3}'.format(test_loss, precision, recall, miss_rate))
# Out:
# Training: Iteration 0, Batch 0, Loss 0.25881287455558777
# Training: Iteration 0, Batch 100, Loss 0.10124887526035309
# Training: Iteration 0, Batch 200, Loss 0.08501636981964111
# Training: Iteration 0, Batch 300, Loss 0.08989463001489639
# Training: Iteration 0, Batch 400, Loss 0.062349364161491394
# Training: Iteration 0, Batch 500, Loss 0.07847148180007935
# Training: Iteration 0, Batch 600, Loss 0.06649202108383179
# Training: Iteration 0, Batch 700, Loss 0.05057813227176666
# Training: Iteration 0, Batch 800, Loss 0.07049056887626648
# Training: Iteration 0, Batch 900, Loss 0.07940644770860672
# Training: Iteration 0, Batch 1000, Loss 0.0465458519756794
# Training: Iteration 0, Batch 1100, Loss 0.05627273768186569
# Training: Iteration 0, Batch 1200, Loss 0.05367976054549217
# Training: Iteration 0, Batch 1300, Loss 0.0653342604637146
# Training: Iteration 0, Batch 1400, Loss 0.05922418087720871
# Training: Iteration 0, Batch 1500, Loss 0.07737191766500473
# Training: Iteration 0, Batch 1600, Loss 0.06352695822715759
# Training: Iteration 0, Batch 1700, Loss 0.05739947035908699
# Training: Iteration 0, Batch 1800, Loss 0.05262676253914833
# Training: Iteration 0, Batch 1900, Loss 0.060966718941926956
# Training: Iteration 0, Batch 2000, Loss 0.05777018144726753
# Training: Iteration 0, Batch 2100, Loss 0.05580751225352287
# Training: Iteration 0, Batch 2200, Loss 0.061872173100709915
# Training: Iteration 0, Batch 2300, Loss 0.041463471949100494
# Training: Iteration 0, Batch 2400, Loss 0.042442549020051956
# Training: Iteration 0, Batch 2500, Loss 0.056620847433805466
# Training: Iteration 0, Batch 2600, Loss 0.03743365779519081
# Training: Iteration 0, Batch 2700, Loss 0.05495445802807808
# Training: Iteration 0, Batch 2800, Loss 0.04458016902208328
# Training: Iteration 0, Batch 2900, Loss 0.04008689895272255
# Training: Iteration 0, Batch 3000, Loss 0.03211499750614166
# Training: Iteration 0, Batch 3100, Loss 0.049770332872867584
# Testing: Iteration 0, Batch 0, Loss 0.04774148017168045, Precision 1.0, Recall 0.3333333333333333, Miss 0.06249997764825821
# Testing: Iteration 0, Batch 100, Loss 0.041178930550813675, Precision 1.0, Recall 0.46153846153846156, Miss 0.05468748137354851
# Testing: Iteration 0, Batch 200, Loss 0.03575572371482849, Precision 1.0, Recall 0.375, Miss 0.039062488824129105
# Testing: Iteration 0, Batch 300, Loss 0.04074500873684883, Precision 1.0, Recall 0.6275, Miss 0.0466068759560585
# Testing: Iteration 0, Batch 400, Loss 0.034627076238393784, Precision 1.0, Recall 0.5454545454545454, Miss 0.039062488824129105
# Testing: Iteration 0, Batch 500, Loss 0.0407547689974308, Precision 1.0, Recall 0.1111111111111111, Miss 0.06249998137354851
# Testing: Iteration 0, Batch 600, Loss 0.04475368186831474, Precision 1.0, Recall 0.21307692307692308, Miss 0.07990138977766037
# Testing: Iteration 0, Batch 700, Loss 0.034328386187553406, Precision 1.0, Recall 0.36363636363636365, Miss 0.054687485098838806
# Testing: Loss 0.04082099686774528, Precision 0.980932359621699, Recall 0.4140015382382028, Miss 0.05508570745587349
# Training: Iteration 1, Batch 0, Loss 0.030813798308372498
# Training: Iteration 1, Batch 100, Loss 0.05002574995160103
# Training: Iteration 1, Batch 200, Loss 0.036208946257829666
# Training: Iteration 1, Batch 300, Loss 0.030213613063097
# Training: Iteration 1, Batch 400, Loss 0.03173980861902237
# Training: Iteration 1, Batch 500, Loss 0.04981468617916107
# Training: Iteration 1, Batch 600, Loss 0.04325074702501297
# Training: Iteration 1, Batch 700, Loss 0.04062410071492195
# Training: Iteration 1, Batch 800, Loss 0.03196785971522331
# Training: Iteration 1, Batch 900, Loss 0.04155443608760834
# Training: Iteration 1, Batch 1000, Loss 0.038468990474939346
# Training: Iteration 1, Batch 1100, Loss 0.045511193573474884
# Training: Iteration 1, Batch 1200, Loss 0.03294306993484497
# Training: Iteration 1, Batch 1300, Loss 0.046285223215818405
# Training: Iteration 1, Batch 1400, Loss 0.025255734100937843
# Training: Iteration 1, Batch 1500, Loss 0.04430537670850754
# Training: Iteration 1, Batch 1600, Loss 0.026753855869174004
# Training: Iteration 1, Batch 1700, Loss 0.023868834599852562
# Training: Iteration 1, Batch 1800, Loss 0.023200975731015205
# Training: Iteration 1, Batch 1900, Loss 0.023844458162784576
# Training: Iteration 1, Batch 2000, Loss 0.022007113322615623
# Training: Iteration 1, Batch 2100, Loss 0.03249778598546982
# Training: Iteration 1, Batch 2200, Loss 0.02155076526105404
# Training: Iteration 1, Batch 2300, Loss 0.015576587989926338
# Training: Iteration 1, Batch 2400, Loss 0.03212790936231613
# Training: Iteration 1, Batch 2500, Loss 0.017725637182593346
# Training: Iteration 1, Batch 2600, Loss 0.023348970338702202
# Training: Iteration 1, Batch 2700, Loss 0.015342160128057003
# Training: Iteration 1, Batch 2800, Loss 0.024256011471152306
# Training: Iteration 1, Batch 2900, Loss 0.04808155819773674
# Training: Iteration 1, Batch 3000, Loss 0.028933241963386536
# Training: Iteration 1, Batch 3100, Loss 0.03159720450639725
# Testing: Iteration 1, Batch 0, Loss 0.02826075069606304, Precision 1.0, Recall 0.9018181818181819, Miss 0.008460876531898975
# Testing: Iteration 1, Batch 100, Loss 0.04201272502541542, Precision 0.875, Recall 0.5833333333333334, Miss 0.039062488824129105
# Testing: Iteration 1, Batch 200, Loss 0.03473168611526489, Precision 0.875, Recall 0.5833333333333334, Miss 0.039062488824129105
# Testing: Iteration 1, Batch 300, Loss 0.019638586789369583, Precision 0.9018645731108931, Recall 0.8354545454545454, Miss 0.014060910791158676
# Testing: Iteration 1, Batch 400, Loss 0.033401913940906525, Precision 0.8465080583269379, Recall 0.6488235294117647, Miss 0.04674287140369415
# Testing: Iteration 1, Batch 500, Loss 0.024096766486763954, Precision 0.8201438848920863, Recall 0.8290909090909091, Miss 0.0148583073168993
# Testing: Iteration 1, Batch 600, Loss 0.014938660897314548, Precision 0.875, Recall 1.0, Miss 0.0
# Testing: Iteration 1, Batch 700, Loss 0.02318098396062851, Precision 0.8666666666666667, Recall 1.0, Miss 0.0
# Testing: Loss 0.02510399480476556, Precision 0.9277596879798491, Recall 0.8373571964206853, Miss 0.01537421252578497
# Training: Iteration 2, Batch 0, Loss 0.02468746528029442
# Training: Iteration 2, Batch 100, Loss 0.024889463558793068
# Training: Iteration 2, Batch 200, Loss 0.02817915380001068
# Training: Iteration 2, Batch 300, Loss 0.021514419466257095
# Training: Iteration 2, Batch 400, Loss 0.032814834266901016
# Training: Iteration 2, Batch 500, Loss 0.02962408773601055
# Training: Iteration 2, Batch 600, Loss 0.020119255408644676
# Training: Iteration 2, Batch 700, Loss 0.024173254147171974
# Training: Iteration 2, Batch 800, Loss 0.013643729500472546
# Training: Iteration 2, Batch 900, Loss 0.02402324602007866
# Training: Iteration 2, Batch 1000, Loss 0.027240192517638206
# Training: Iteration 2, Batch 1100, Loss 0.033560194075107574
# Training: Iteration 2, Batch 1200, Loss 0.019706139340996742
# Training: Iteration 2, Batch 1300, Loss 0.02709069661796093
# Training: Iteration 2, Batch 1400, Loss 0.021931258961558342
# Training: Iteration 2, Batch 1500, Loss 0.025035545229911804
# Training: Iteration 2, Batch 1600, Loss 0.029006212949752808
# Training: Iteration 2, Batch 1700, Loss 0.025416940450668335
# Training: Iteration 2, Batch 1800, Loss 0.024407966062426567
# Training: Iteration 2, Batch 1900, Loss 0.01710941456258297
# Training: Iteration 2, Batch 2000, Loss 0.017413493245840073
# Training: Iteration 2, Batch 2100, Loss 0.02185049094259739
# Training: Iteration 2, Batch 2200, Loss 0.014933663420379162
# Training: Iteration 2, Batch 2300, Loss 0.020551757887005806
# Training: Iteration 2, Batch 2400, Loss 0.021540405228734016
# Training: Iteration 2, Batch 2500, Loss 0.021398264914751053
# Training: Iteration 2, Batch 2600, Loss 0.029263446107506752
# Training: Iteration 2, Batch 2700, Loss 0.024410387501120567
# Training: Iteration 2, Batch 2800, Loss 0.036278512328863144
# Training: Iteration 2, Batch 2900, Loss 0.015998737886548042
# Training: Iteration 2, Batch 3000, Loss 0.012279237620532513
# Training: Iteration 2, Batch 3100, Loss 0.015345444902777672
# Testing: Iteration 2, Batch 0, Loss 0.027431711554527283, Precision 1.0, Recall 0.8252941176470588, Miss 0.023270949721336365
# Testing: Iteration 2, Batch 100, Loss 0.017572632059454918, Precision 1.0, Recall 0.875, Miss 0.0078124976716935635
# Testing: Iteration 2, Batch 200, Loss 0.034647416323423386, Precision 1.0, Recall 0.7290909090909091, Miss 0.04656883329153061
# Testing: Iteration 2, Batch 300, Loss 0.016546763479709625, Precision 0.9, Recall 0.9, Miss 0.0078124976716935635
# Testing: Iteration 2, Batch 400, Loss 0.030030356720089912, Precision 1.0, Recall 0.668, Miss 0.038863617926836014
# Testing: Iteration 2, Batch 500, Loss 0.03278117626905441, Precision 0.9090909090909091, Recall 0.7142857142857143, Miss 0.031249990686774254
# Testing: Iteration 2, Batch 600, Loss 0.025998026132583618, Precision 0.875, Recall 0.6363636363636364, Miss 0.031249990686774254
# Testing: Iteration 2, Batch 700, Loss 0.015564859844744205, Precision 1.0, Recall 0.7475, Miss 0.01581747643649578
# Testing: Loss 0.019782228061876943, Precision 0.9735975306648508, Recall 0.8167610839484714, Miss 0.01701875776052475
# Training: Iteration 3, Batch 0, Loss 0.022595936432480812
# Training: Iteration 3, Batch 100, Loss 0.013123693875968456
# Training: Iteration 3, Batch 200, Loss 0.023646099492907524
# Training: Iteration 3, Batch 300, Loss 0.018612761050462723
# Training: Iteration 3, Batch 400, Loss 0.01446486171334982
# Training: Iteration 3, Batch 500, Loss 0.01773635856807232
# Training: Iteration 3, Batch 600, Loss 0.020455757156014442
# Training: Iteration 3, Batch 700, Loss 0.02160792425274849
# Training: Iteration 3, Batch 800, Loss 0.013909034430980682
# Training: Iteration 3, Batch 900, Loss 0.025198081508278847
# Training: Iteration 3, Batch 1000, Loss 0.021618088707327843
# Training: Iteration 3, Batch 1100, Loss 0.014683268032968044
# Training: Iteration 3, Batch 1200, Loss 0.01202706340700388
# Training: Iteration 3, Batch 1300, Loss 0.03548933193087578
# Training: Iteration 3, Batch 1400, Loss 0.015805650502443314
# Training: Iteration 3, Batch 1500, Loss 0.016126271337270737
# Training: Iteration 3, Batch 1600, Loss 0.023599687963724136
# Training: Iteration 3, Batch 1700, Loss 0.022438382729887962
# Training: Iteration 3, Batch 1800, Loss 0.011093392968177795
# Training: Iteration 3, Batch 1900, Loss 0.019272154197096825
# Training: Iteration 3, Batch 2000, Loss 0.018498346209526062
# Training: Iteration 3, Batch 2100, Loss 0.02053287997841835
# Training: Iteration 3, Batch 2200, Loss 0.020958416163921356
# Training: Iteration 3, Batch 2300, Loss 0.018114743754267693
# Training: Iteration 3, Batch 2400, Loss 0.018376421183347702
# Training: Iteration 3, Batch 2500, Loss 0.010355968028306961
# Training: Iteration 3, Batch 2600, Loss 0.016769221052527428
# Training: Iteration 3, Batch 2700, Loss 0.016358809545636177
# Training: Iteration 3, Batch 2800, Loss 0.015478462912142277
# Training: Iteration 3, Batch 2900, Loss 0.008833659812808037
# Training: Iteration 3, Batch 3000, Loss 0.01098672579973936
# Training: Iteration 3, Batch 3100, Loss 0.013918397016823292
# Testing: Iteration 3, Batch 0, Loss 0.017860649153590202, Precision 0.9375, Recall 0.8823529411764706, Miss 0.015624995343387127
# Testing: Iteration 3, Batch 100, Loss 0.016351288184523582, Precision 1.0, Recall 0.9444444444444444, Miss 0.0078124976716935635
# Testing: Iteration 3, Batch 200, Loss 0.012836004607379436, Precision 1.0, Recall 0.9036363636363637, Miss 0.008275055326521397
# Testing: Iteration 3, Batch 300, Loss 0.015176241286098957, Precision 1.0, Recall 0.8461538461538461, Miss 0.015624995343387127
# Testing: Iteration 3, Batch 400, Loss 0.024821145460009575, Precision 0.9, Recall 0.9, Miss 0.0078124976716935635
# Testing: Iteration 3, Batch 500, Loss 0.015915896743535995, Precision 1.0, Recall 0.8888888888888888, Miss 0.0078124976716935635
# Testing: Iteration 3, Batch 600, Loss 0.016414431855082512, Precision 0.9, Recall 0.8181818181818182, Miss 0.015624995343387127
# Testing: Iteration 3, Batch 700, Loss 0.017339587211608887, Precision 1.0, Recall 0.7142857142857143, Miss 0.015624995343387127
# Testing: Loss 0.0160823864314486, Precision 0.9694453334932019, Recall 0.9008388995147176, Miss 0.00930542591959238
# Training: Iteration 4, Batch 0, Loss 0.0249526035040617
# Training: Iteration 4, Batch 100, Loss 0.010107538662850857
# Training: Iteration 4, Batch 200, Loss 0.015894630923867226
# Training: Iteration 4, Batch 300, Loss 0.010605382733047009
# Training: Iteration 4, Batch 400, Loss 0.014401142485439777
# Training: Iteration 4, Batch 500, Loss 0.01581900753080845
# Training: Iteration 4, Batch 600, Loss 0.0036467621102929115
# Training: Iteration 4, Batch 700, Loss 0.016509046778082848
# Training: Iteration 4, Batch 800, Loss 0.013846974819898605
# Training: Iteration 4, Batch 900, Loss 0.017145736142992973
# Training: Iteration 4, Batch 1000, Loss 0.018663449212908745
# Training: Iteration 4, Batch 1100, Loss 0.016975505277514458
# Training: Iteration 4, Batch 1200, Loss 0.011790861375629902
# Training: Iteration 4, Batch 1300, Loss 0.015455798245966434
# Training: Iteration 4, Batch 1400, Loss 0.01392074953764677
# Training: Iteration 4, Batch 1500, Loss 0.013262874446809292
# Training: Iteration 4, Batch 1600, Loss 0.014732107520103455
# Training: Iteration 4, Batch 1700, Loss 0.014004215598106384
# Training: Iteration 4, Batch 1800, Loss 0.007910891436040401
# Training: Iteration 4, Batch 1900, Loss 0.012699028477072716
# Training: Iteration 4, Batch 2000, Loss 0.013259142637252808
# Training: Iteration 4, Batch 2100, Loss 0.018834548071026802
# Training: Iteration 4, Batch 2200, Loss 0.017074165865778923
# Training: Iteration 4, Batch 2300, Loss 0.006931488402187824
# Training: Iteration 4, Batch 2400, Loss 0.01116203423589468
# Training: Iteration 4, Batch 2500, Loss 0.01322265900671482
# Training: Iteration 4, Batch 2600, Loss 0.009944750927388668
# Training: Iteration 4, Batch 2700, Loss 0.014472451992332935
# Training: Iteration 4, Batch 2800, Loss 0.00853861402720213
# Training: Iteration 4, Batch 2900, Loss 0.028980806469917297
# Training: Iteration 4, Batch 3000, Loss 0.0222021471709013
# Training: Iteration 4, Batch 3100, Loss 0.011046943254768848
# Testing: Iteration 4, Batch 0, Loss 0.005559657234698534, Precision 0.8746355685131195, Recall 0.8571428571428571, Miss 0.0078124976716935635
# Testing: Iteration 4, Batch 100, Loss 0.009449943900108337, Precision 1.0, Recall 0.9230769230769231, Miss 0.0078124976716935635
# Testing: Iteration 4, Batch 200, Loss 0.009865781292319298, Precision 1.0, Recall 0.9333333333333333, Miss 0.0078124976716935635
# Testing: Iteration 4, Batch 300, Loss 0.008753283880650997, Precision 1.0, Recall 0.9166666666666666, Miss 0.0078124976716935635
# Testing: Iteration 4, Batch 400, Loss 0.021083105355501175, Precision 1.0, Recall 0.7692307692307693, Miss 0.023437492549419403
# Testing: Iteration 4, Batch 500, Loss 0.01428583636879921, Precision 1.0, Recall 0.9285714285714286, Miss 0.0078124976716935635
# Testing: Iteration 4, Batch 600, Loss 0.014434781856834888, Precision 1.0, Recall 0.8, Miss 0.015624995343387127
# Testing: Iteration 4, Batch 700, Loss 0.006980440113693476, Precision 1.0, Recall 1.0, Miss 0.0
# Testing: Loss 0.01526375837317999, Precision 0.9867390230134514, Recall 0.8163225979023201, Miss 0.017124297097325325

# %%
(distances[2], features[2])

# %%
for name, param in model.thres1.named_parameters():
    print (name, param.data)

# %%
torch.save(model.state_dict(), '/home/sunji/ANN/nytimes_256_angular/saved_models/global_nytimes_256_angular_punish_query_threshold_monotonic.model')

# %% [markdown]
# ## Model Usage

# %%
model = Model()
model.load_state_dict(torch.load('global_fashion_mnist_784_euclidean_binary_query_threshold.model'))
model.eval()
# Out:
# Model(
#   (nn1): Linear(in_features=785, out_features=256, bias=True)
#   (nn2): Linear(in_features=256, out_features=256, bias=True)
#   (nn3): Linear(in_features=256, out_features=256, bias=True)
#   (nn4): Linear(in_features=256, out_features=100, bias=True)
# )

# %%
for batch_idx, (features, thresholds, distances, targets, cards) in enumerate(test_loader):
    x = Variable(features)
    y = Variable(targets.unsqueeze(1))
    z = Variable(thresholds)
    dist = Variable(distances)
    estimates = model(x, dist, z)
    loss = loss_fn(estimates, targets, cards)
    prec, rec, miss_rate = print_loss(estimates, targets, cards)
    print (loss.item(), prec, rec, miss_rate)
#     print (targets[0])
# Out:
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011616033501923084 0.9865168539325843 0.9653655854865311 tensor(0.0307)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.013758893124759197 0.9868929952728835 0.9659305993690852 tensor(0.0149)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.010944121517241001 0.9889834752128193 0.9657701711491442 tensor(0.0170)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.012130827642977238 0.9878915504080021 0.9596011250319612 tensor(0.0179)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011950699612498283 0.9855285749325484 0.972645848462842 tensor(0.0386)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.014175038784742355 0.9893148962916405 0.9622987568779295 tensor(0.0226)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.014790528453886509 0.9867578900904878 0.9652417962003454 tensor(0.0361)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.01132373046129942 0.9918009612666101 0.9592562209461307 tensor(0.0334)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.01490761712193489 0.9856217091940057 0.9689428628309775 tensor(0.0043)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.013611814007163048 0.9878243512974052 0.9664128099980472 tensor(0.0165)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.01533545833081007 0.9882304356803634 0.9620100502512563 tensor(0.0020)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.013402558863162994 0.985386690647482 0.9658439841339798 tensor(0.0369)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.012438501231372356 0.9876464323748669 0.9715063901110412 tensor(0.0238)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011510196141898632 0.9892645043398812 0.9676050044682752 tensor(0.0215)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011357973329722881 0.9818237831176833 0.963422007255139 tensor(0.0103)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011999377980828285 0.9858916478555305 0.9622693472872487 tensor(0.0185)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011021489277482033 0.9905447996398019 0.9678838539375275 tensor(0.0184)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.01258517149835825 0.985634477254589 0.9671104150352389 tensor(0.0303)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.0109231136739254 0.9849644614543467 0.970113085621971 tensor(0.0210)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.014314117841422558 0.9891278086494323 0.9549801726148822 tensor(0.0079)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.010538735426962376 0.985855013892397 0.9689672293942403 tensor(0.0122)
# total_card:  torch.Size([128])
# miss_card:  torch.Size([128])
# 0.011180868372321129 0.988537880905787 0.9637503406922867 tensor(0.0323)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-a20c1e944ddd> in <module>
#       6     estimates = model(x, dist, z)
#       7     loss = loss_fn(estimates, targets, cards)
# ----> 8     prec, rec, miss_rate = print_loss(estimates, targets, cards)
#       9     print (loss.item(), prec, rec, miss_rate)
#      10 #     print (targets[0])
#
# <ipython-input-38-dff79b58f867> in print_loss(estimates, targets, cards)
#      62             elif est[i] < 0.5 and tar[i] == 1:
#      63                 false_positive += 1
# ---> 64             elif est[i] >= 0.5 and tar[i] == 0:
#      65                 false_negative += 1
#      66             else:
#
# KeyboardInterrupt:

# %%
use_cuda = torch.cuda.is_available()

#     torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")
train_dataset = np.array(f['train'])
test_dataset = np.array(f['test'])
train_lefts, train_rights, test_lefts, test_rights = prepare_dataset(train_dataset, test_dataset, train_num, test_num)

train_loader = torch.utils.data.DataLoader(
    (train_lefts, train_rights), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    (test_lefts, test_rights), batch_size=batch_size, shuffle=True)

# %%
# hash_distances, input_distances = test(model, device, train_loader)
hash_distances, input_distances = test(model, device, test_loader)

# %%
lefts = torch.FloatTensor([f['train'][0] for x in range(999)])
rights = torch.FloatTensor(f['train'][1:1000])
inputdistance = angular_distance(lefts, rights).detach().numpy()
hashdistance = l1_distance(model(lefts), model(rights)).detach().numpy()

# %%
# for xx in zip(inputdistance, hashdistance):
#     print (xx[0], xx[1])
index_1 = np.argsort(hashdistance, 0)
index_2 = np.argsort(inputdistance, 0)
# np.random.shuffle(index_2)

input_index = {}
for pos, idx in enumerate(index_2):
    input_index[idx] = pos
sum = 0.0
for pos, idx in enumerate(index_1):
    sum += np.abs(pos - input_index[idx])
sum / len(index_1)

# %%
xxx = np.sort(inputdistance, 0)
plt.plot(xxx)
plt.show()

# %%
import math
distances = []
for i in index_1:
    distances.append(math.floor(inputdistance[i].item()* 40))

# %%
import matplotlib.pyplot as plt

plt.plot(distances)
plt.show()

# %%
F.cosine_similarity(torch.FloatTensor(f['train'][0]).unsqueeze(0), torch.FloatTensor(f['train'][6]).unsqueeze(0), dim=1, eps=1e-8)

# %%
for x, y in zip(hash_distances[0][0:30], input_distances[0][0:30]):
    print (x, y)

# %%
dataset_vector = model(torch.FloatTensor(f['train']))

# %%
query_vector = model(torch.FloatTensor(f['test']))

# %%
def binarization(vector):
    query_codes = []
    for v in vector:
        binary_code = []
        for e in v:
            if e < 0.5:
                binary_code.append(0)
            else:
                binary_code.append(1)
        query_codes.append(binary_code)
    return np.array(query_codes)
dataset_binary = binarization(dataset_vector.detach().numpy())
query_binary = binarization(query_vector.detach().numpy())

# %%
len(dataset_binary)

# %%
len(query_binary)

# %%
import math
hash_table = {}
for idx, point in enumerate(dataset_binary):
    pos = 0
    key = 0
    for d in point:
        key += d * math.pow(2, pos)
        pos += 1
    if key in hash_table:
        hash_table[key].append(idx)
    else:
        hash_table[key] = [idx]

# %%
f['neighbors'][:]

# %%
def find_candidate_distance(vector, hash_table, candidate_num):
    candidate = []
    for point in query_binary:
        cand = []
        dis = 0
        while len(cand) < 100:
            pos = 0
            key = 0
            for d in point:
                key += d * math.pow(2, pos)
                pos += 1
            if key in hash_table:
                candidate.append(hash_table[key])
    return candidate
find_candidate_0_distance(query_binary, hash_table)

# %%
class Node(object):
    def __init__(hash_code, data_index_set):
        self.hash_code = hash_code
        self.data_index_set = data_index_set
        self.children = []
        
    def isLeaf():
        return len(self.children) == 0
    
    def train(dataset):
        train_data = dataset[self.data_index_set]
        self.model = train(dataset)
        
    def partition():
        points = dataset[self.data_index_set]
        hash_table = {}
        codes = self.model(points)
        for idx, code in enumerate(codes):
            if code in hash_table:
                hash_table[code].append(self.data_index_set[idx])
            else:
                hash_table[code] = [self.data_index_set[idx]]
        for key,value in d.items():
            self.children.append(Node(key, value))
    
    def search(query, dataset):
        if self.isLeaf():
            return validate(dataset[self.data_index_set])
        else:
            children_idxes = select_children(query)
            result = []
            for idx in children_idxes:
                result += self.children[idx].search(query, dataset)
            return result
    
    
    

def index_construction(dataset):
    model = train(dataset)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold, datasets

data = np.array(f['train'])

tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(data[np.random.choice(data.shape[0], 100000, replace=False)])
